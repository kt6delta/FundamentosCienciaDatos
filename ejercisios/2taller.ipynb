# %%
import numpy as np #arreiglos
a = int(input("# cubo (del 1 al 27): "))
b = int(input("# cubo (del 1 al 27): "))

def cambiar(i,j):
  n = np.arange(729).reshape(9,9,9)
  n=np.reshape(n,(27,3,3,3))
  temp=n[(i-1):i,0:3,0:3,0:3] 
  temp2=n[(j-1):j,0:3,0:3,0:3] 
  print(temp2)
  for u in range(0,3):
      for f in range(0,3):
          for c in range(0,3): 
              n[j-1][u][f][c]=temp[0][u][f][c]
              n[i-1][u][f][c]=temp2[0][u][f][c]
  print(temp)
cambiar(a,b)

# %% [markdown]
# linear algebra.py

# %%
import numpy as np #arreiglos
n = np.arange(12).reshape(2,2,3)
print("original")
print(n)
a=np.arange(-6,0).reshape(2,3)
b=np.arange(12,18).reshape(2,3)

for f in range (0,2):
    for c in range (0,3):
        n[0][f][c]=a[f][c]
        n[1][f][c]=b[f][c]
        
print("queda ")
print(n)

# %%
datos = [0,0,0,0,0,0]
for i in range(1,7):
    datos[i-1] = int( input( "Dime el dato numero {}: ".format(i) ))
print ("Los datos al reves son: ")
for i in range(6,0,-1):
    print ( datos[i-1] )
