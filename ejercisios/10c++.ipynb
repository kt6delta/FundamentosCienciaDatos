# %% [markdown]
# primero GPU

# %%
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update

# %%
# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 -O cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda-9.2

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Wed_Apr_11_23:16:29_CDT_2018
# Cuda compilation tools, release 9.2, V9.2.88

# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git

# %%
# %load_ext nvcc_plugin

# %%
# %%cu
# #include <iostream>
# using namespace std;
#
# int main()
# {
#     int age;
#
#     cout << "Enter your age:";
#     cin >> age;
#     cout << "\nYour age is: " << age << endl;
#
#     return 0;
# }
# Out:
# UsageError: Cell magic `%%cu` not found.

# %%
# %%cu
# #include <iostream>
# using namespace std;
#
# int main()
# {
#     int array[4];
#     int array2[4];
#     int n=0;
#     while(!(0>n & n<9999)){
#      cin>>n;
#     }
#    for(int i=0; i<n; i++){
#         int num;
#         cin>>num;
#         int conta=0;
#
#         while (!(num==6174 || num==0)){
#           array[0]=int(num/10000);
#           float a1= a-(num/1000);
#           array[1]=int(a1*10);
#           float c1=array[1]-a1;
#           array[2]=c1*10;
#           array[3]=(array[2]-c1)*10;
#
#           for(int j=0 ; j<4; j++){
#               for(int l=0; l<4; l++){
#                  if(array[j]<array[l]){
#                   int temp= array[j];
#                   array[j]=array[l];
#                   array[l]=temp;
#                 }
#               }
#           }
#           for(int j=0 ; j<4; j++){
#               for(int l=0; l<4; l++){
#                  if(array2[j]>array2[l]){
#                   int temp= array2[j];
#                   array2[j]=array2[l];
#                   array2[l]=temp;
#                 }
#               }
#           }
#           int num1=array[0]*1000+array[1]*100+array[2]*10+array[3];
#           int num2=array2[0]*1000+array2[1]*100+array2[2]*10+array2[3];
#           if(num1>num2){
#               num=num1-num2;
#           }else{
#               num=num2-num1;
#           }
#           conta++;
#         }
#         if(num==0){
#             conta=8;
#         }
#         cout>>conta>>endl;
#     }
#     return 0;
# }
