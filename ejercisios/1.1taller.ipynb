# %%
import numpy as np
def corte(n1,n2):
#z,y,x
    cont=-1
    posi1=[]
    posi2=[]
    for z in range(0,7,3):
        for y in range(0,7,3):
            for x in range(0,7,3):
                for mat in range (0,3,1):
                    if(mat==0):
                        cont=cont+1  
                    if(cont==n1):
                        a[mat+z, y:y+3, x:x+3]
                        if(mat==0):
                            posi1=[z,y,x]
                    if(cont==n2):
                        a[mat+z, y:y+3, x:x+3]
                        if(mat==0):
                            posi2=[z,y,x]
    for i in range(0,3):                        
        temp=a[posi1[0]+i, posi1[1]:posi1[1]+3, posi1[2]:posi1[2]+3].copy()
        a[posi1[0]+i, posi1[1]:posi1[1]+3, posi1[2]:posi1[2]+3]=a[posi2[0]+i, posi2[1]:posi2[1]+3, posi2[2]:posi2[2]+3].copy() 
        a[posi2[0]+i, posi2[1]:posi2[1]+3, posi2[2]:posi2[2]+3]=temp
    
    print("")
    print(a)
a=np.arange(729).reshape(9,9,9)
b =int(input("Introduce cubo a intercambiar: "))
c=int(input("Introduce cubo a intercambiar: "))
corte(b, c)
