# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Sep  5 08:02:53 2018

@author: Nelson
"""

import numpy as np

# Basic linear algebra

a = np.array([[1.0, 2.0], [3.0, 4.0]])
u = np.eye(2)
print(a)
print(u)

print(a.transpose())

print(u.trace())

# Matrix product

print(a@u)
print(a@a)

# TALLER: Realizar un tutorial tipo Notebook (jupyter) de linalg
# inv, det, solve, ....
