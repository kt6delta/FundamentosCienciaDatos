# %%
for i in range(1,10):
  print("vuelta "+str(i))

# %%
print("ingrese su nombre")
nom=input()
print("hola "+ nom)
n=len(nom)
print(nom+" tiene "+str(n)+" letras")
print("su nombre se repetira:")
num=input()
for j in range(int(num)):
  print(nom)

# %%
print(pow(3+2/2*5, 2))

# %%
print("peso")
p=input()
print("altura")
h=input()
print("tu IMC es: "+str(round(float (p)/(float (h)**2),2)))

# %%
contraseña=input()
if (contraseña=="kt" or contraseña=="Kt" or contraseña=="KT" or contraseña=="kT"):
  print("correcto")
else:
  print("intente otra vez")

# %%
import numpy as np
l=np.zeros(10)
for i in range(10):
  n=input()
  l[i]=int(n)
for j in range (10):
  if (l[j]%2==0):
    print(str(int(l[j])), end=" ")

# %%
import numpy as np
