# %%
import numpy as np
import pandas as pd

temp = np.random.randint(low=0, high=10, size=(5, 3))
df = pd.DataFrame(data=temp, columns=['A', 'B', 'C'])

#def columna(A,B,C):
 # colum=[A,B,C]
  #df.columns
  #return df

df.head()
#print(columna('S','P','R'))

# %%
import random
a= random.randint(0, 99)
b=-1
c= False
for f in list(range(10,0,-1)):
    if(a==b):
        c=True
        break
    else:
        b = int(input("Introduce un numero: ")) 
        if(a<b):
            if(b-a<10):
                print("estas cerca")
            print("es menor ") 
        else:
            if(a-b<10):
                print("estas cerca")
            print("es mayor ") 
if(c):
    print("You win")
    f=f+1
else:
    print("You lost")
    f=f-1
f=(f*10)
print("score:")
print(f)
print("el numero era:")
print(a)
